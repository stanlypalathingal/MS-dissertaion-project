# %%
# %autosave 20
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Autosaving every 20 seconds

# %%
df=pd.read_csv("C:/Users/HP/OneDrive - Newcastle University/Dissertation/Data_sets/training_data.csv")
# df_s=df_s.drop("Key",1)
df=df.dropna()
print("sample before ",df.shape)
# Out:
# sample before  (377203, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377203 entries, 0 to 377202
# Data columns (total 6 columns):
# Sensor    377203 non-null object
# Type      377203 non-null object
# Units     377203 non-null object
# time      377203 non-null object
# Flag      377203 non-null float64
# Value     377203 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 20.1+ MB

# %%
df.nunique()
# Out:
# Sensor        3
# Type         12
# Units         6
# time      42368
# Flag          2
# Value     89715
# dtype: int64

# %%
def plot_cloumns_individual(columnName,type="bar"):
    x=1
    for i in columnName:
        fig.add_subplot(1,3,x)
#         print(df[i].value_counts())
        df[i].value_counts().plot(kind=type)
#         plt.xlabel(i)
#         plt.ylabel("Count")
        plt.title(i)
        plt.xticks(rotation=45)
        x=x+1

# %%
# plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
plot_cloumns_individual(["Sensor","Type","Units"],"bar")
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
plot_cloumns_individual(["Sensor","Type","Units"],"pie")
plt.show()

# %%
df.groupby("Type")["Sensor"].count()
# Out:
# Type
# CO             30478
# Humidity       33328
# NO             33953
# NO2            34003
# O3              4262
# PM 4           58530
# PM1            58687
# PM10           58689
# PM2.5          58695
# Pressure        4240
# Sound          28326
# Temperature    33946
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type","Units"])["Sensor"].count()
# Out:
# Sensor                  Type         Units
# PER_AIRMON_MESH1911150  CO           ugm -3      3209
#                         Humidity     %           3192
#                         NO           ugm -3      3192
#                         NO2          ugm -3      3207
#                         O3           ppb         3204
#                         PM 4         ugm -3     45125
#                         PM1          ugm -3     45284
#                         PM10         ugm -3     45270
#                         PM2.5        ugm -3     45291
#                         Pressure     hpa         3192
#                         Temperature  Celsius     3192
# PER_AIRMON_MESH301245   Humidity     %           3122
#                         NO           ugm -3      3122
#                         NO2          ugm -3      3145
#                         O3           ppb         3130
#                         PM 4         ugm -3     42709
#                         PM1          ugm -3     42707
#                         PM10         ugm -3     42708
#                         PM2.5        ugm -3     42708
#                         Pressure     hpa         3122
#                         Temperature  Celsius     3122
# PER_EMOTE_1309          CO           ugm -3     40841
#                         Humidity     %          41623
#                         NO           ugm -3     42244
#                         NO2          ugm -3     42258
#                         Sound        db         40861
#                         Temperature  Celsius    42241
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Sensor","Units"])["Sensor"].count()
# Out:
# Type         Sensor                  Units
# CO           PER_AIRMON_MESH1911150  ugm -3      2172
#              PER_EMOTE_1309          ugm -3     28306
# Humidity     PER_AIRMON_MESH1911150  %           2155
#              PER_AIRMON_MESH301245   %           2085
#              PER_EMOTE_1309          %          29088
# NO           PER_AIRMON_MESH1911150  ugm -3      2155
#              PER_AIRMON_MESH301245   ugm -3      2085
#              PER_EMOTE_1309          ugm -3     29713
# NO2          PER_AIRMON_MESH1911150  ugm -3      2170
#              PER_AIRMON_MESH301245   ugm -3      2109
#              PER_EMOTE_1309          ugm -3     29724
# O3           PER_AIRMON_MESH1911150  ppb         2168
#              PER_AIRMON_MESH301245   ppb         2094
# PM 4         PER_AIRMON_MESH1911150  ugm -3     30529
#              PER_AIRMON_MESH301245   ugm -3     28001
# PM1          PER_AIRMON_MESH1911150  ugm -3     30688
#              PER_AIRMON_MESH301245   ugm -3     27999
# PM10         PER_AIRMON_MESH1911150  ugm -3     30689
#              PER_AIRMON_MESH301245   ugm -3     28000
# PM2.5        PER_AIRMON_MESH1911150  ugm -3     30695
#              PER_AIRMON_MESH301245   ugm -3     28000
# Pressure     PER_AIRMON_MESH1911150  hpa         2155
#              PER_AIRMON_MESH301245   hpa         2085
# Sound        PER_EMOTE_1309          db         28326
# Temperature  PER_AIRMON_MESH1911150  Celsius     2155
#              PER_AIRMON_MESH301245   Celsius     2085
#              PER_EMOTE_1309          Celsius    29706
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Units","Sensor"])["Sensor"].count()
# Out:
# Type         Units    Sensor
# CO           ugm -3   PER_AIRMON_MESH1911150     2172
#                       PER_EMOTE_1309            28306
# Humidity     %        PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29088
# NO           ugm -3   PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29713
# NO2          ugm -3   PER_AIRMON_MESH1911150     2170
#                       PER_AIRMON_MESH301245      2109
#                       PER_EMOTE_1309            29724
# O3           ppb      PER_AIRMON_MESH1911150     2168
#                       PER_AIRMON_MESH301245      2094
# PM 4         ugm -3   PER_AIRMON_MESH1911150    30529
#                       PER_AIRMON_MESH301245     28001
# PM1          ugm -3   PER_AIRMON_MESH1911150    30688
#                       PER_AIRMON_MESH301245     27999
# PM10         ugm -3   PER_AIRMON_MESH1911150    30689
#                       PER_AIRMON_MESH301245     28000
# PM2.5        ugm -3   PER_AIRMON_MESH1911150    30695
#                       PER_AIRMON_MESH301245     28000
# Pressure     hpa      PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
# Sound        db       PER_EMOTE_1309            28326
# Temperature  Celsius  PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29706
# Name: Sensor, dtype: int64

# %%
df.groupby(["Units","Type","Sensor"])["Sensor"].count()
# Out:
# Units    Type         Sensor
# %        Humidity     PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29088
# Celsius  Temperature  PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29706
# db       Sound        PER_EMOTE_1309            28326
# hpa      Pressure     PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
# ppb      O3           PER_AIRMON_MESH1911150     2168
#                       PER_AIRMON_MESH301245      2094
# ugm -3   CO           PER_AIRMON_MESH1911150     2172
#                       PER_EMOTE_1309            28306
#          NO           PER_AIRMON_MESH1911150     2155
#                       PER_AIRMON_MESH301245      2085
#                       PER_EMOTE_1309            29713
#          NO2          PER_AIRMON_MESH1911150     2170
#                       PER_AIRMON_MESH301245      2109
#                       PER_EMOTE_1309            29724
#          PM 4         PER_AIRMON_MESH1911150    30529
#                       PER_AIRMON_MESH301245     28001
#          PM1          PER_AIRMON_MESH1911150    30688
#                       PER_AIRMON_MESH301245     27999
#          PM10         PER_AIRMON_MESH1911150    30689
#                       PER_AIRMON_MESH301245     28000
#          PM2.5        PER_AIRMON_MESH1911150    30695
#                       PER_AIRMON_MESH301245     28000
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type"])["Sensor"].count()
# Out:
# Sensor                  Type
# PER_AIRMON_MESH1911150  CO              2172
#                         Humidity        2155
#                         NO              2155
#                         NO2             2170
#                         O3              2168
#                         PM 4           30529
#                         PM1            30688
#                         PM10           30689
#                         PM2.5          30695
#                         Pressure        2155
#                         Temperature     2155
# PER_AIRMON_MESH301245   Humidity        2085
#                         NO              2085
#                         NO2             2109
#                         O3              2094
#                         PM 4           28001
#                         PM1            27999
#                         PM10           28000
#                         PM2.5          28000
#                         Pressure        2085
#                         Temperature     2085
# PER_EMOTE_1309          CO             28306
#                         Humidity       29088
#                         NO             29713
#                         NO2            29724
#                         Sound          28326
#                         Temperature    29706
# Name: Sensor, dtype: int64

# %%
def combinedPlot(c1,c2,c3,position):
    fig, ax = plt.subplots(figsize=(12,6))
    df.groupby([c1,c2])[c3].count().unstack().plot(ax=ax,kind="bar",stacked=True)
    ax.legend(loc=position,ncol=1, fancybox=True, shadow=True)
    plt.xticks(rotation=0)
    plt.xlabel(c1)
    plt.ylabel("Count")
    plt.title(c1+" Vs "+c2)
    plt.show()

# %%
combinedPlot("Sensor","Type","Units","upper center")

# %%
combinedPlot("Type","Units","Sensor","upper right")

# %%
combinedPlot("Type","Sensor","Sensor","upper left")

# %%
combinedPlot("Sensor","Units","Type","upper center")
