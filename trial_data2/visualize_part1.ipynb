# %%
# %autosave 20
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Autosaving every 20 seconds

# %%
df=pd.read_csv("Sample dataset values1.csv")
# df_s=df_s.drop("Key",1)
df=df.dropna()
print("sample before ",df.shape)
# Out:
# sample before  (241492, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241492 entries, 0 to 241491
# Data columns (total 6 columns):
# Sensor    241492 non-null object
# Type      241492 non-null object
# Units     241492 non-null object
# time      241492 non-null object
# Flag      241492 non-null float64
# Value     241492 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 12.9+ MB

# %%
df.nunique()
# Out:
# Sensor        3
# Type         12
# Units         6
# time      25535
# Flag          2
# Value     61335
# dtype: int64

# %%
def plot_cloumns_individual(columnName,type="bar"):
    x=1
    for i in columnName:
        fig.add_subplot(1,3,x)
#         print(df[i].value_counts())
        df[i].value_counts().plot(kind=type)
        
        plt.title(i)
        plt.xticks(rotation=45)
        x=x+1

# %%
# plt.subplot(2,1,2)
fig = plt.figure(figsize=(15,5))
plot_cloumns_individual(["Sensor","Type","Units"],"bar")
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
plot_cloumns_individual(["Sensor","Type","Units"],"pie")
plt.show()

# %%
df.groupby("Type")["Sensor"].count()
# Out:
# Type
# CO             17392
# Humidity       19300
# NO             19918
# NO2            19929
# O3              2306
# PM 4           31049
# PM1            31047
# PM10           31047
# PM2.5          31048
# Pressure        2306
# Sound          16232
# Temperature    19918
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type","Units"])["Sensor"].count()
# Out:
# Sensor                  Type         Units
# PER_AIRMON_MESH1911150  CO           ugm -3      1180
#                         Humidity     %           1180
#                         NO           ugm -3      1180
#                         NO2          ugm -3      1180
#                         O3           ppb         1180
#                         PM 4         ugm -3     16715
#                         PM1          ugm -3     16713
#                         PM10         ugm -3     16713
#                         PM2.5        ugm -3     16714
#                         Pressure     hpa         1180
#                         Temperature  Celsius     1180
# PER_AIRMON_MESH301245   Humidity     %           1126
#                         NO           ugm -3      1126
#                         NO2          ugm -3      1126
#                         O3           ppb         1126
#                         PM 4         ugm -3     14334
#                         PM1          ugm -3     14334
#                         PM10         ugm -3     14334
#                         PM2.5        ugm -3     14334
#                         Pressure     hpa         1126
#                         Temperature  Celsius     1126
# PER_EMOTE_1309          CO           ugm -3     16212
#                         Humidity     %          16994
#                         NO           ugm -3     17612
#                         NO2          ugm -3     17623
#                         Sound        db         16232
#                         Temperature  Celsius    17612
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Sensor","Units"])["Sensor"].count()
# Out:
# Type         Sensor                  Units
# CO           PER_AIRMON_MESH1911150  ugm -3      1180
#              PER_EMOTE_1309          ugm -3     16212
# Humidity     PER_AIRMON_MESH1911150  %           1180
#              PER_AIRMON_MESH301245   %           1126
#              PER_EMOTE_1309          %          16994
# NO           PER_AIRMON_MESH1911150  ugm -3      1180
#              PER_AIRMON_MESH301245   ugm -3      1126
#              PER_EMOTE_1309          ugm -3     17612
# NO2          PER_AIRMON_MESH1911150  ugm -3      1180
#              PER_AIRMON_MESH301245   ugm -3      1126
#              PER_EMOTE_1309          ugm -3     17623
# O3           PER_AIRMON_MESH1911150  ppb         1180
#              PER_AIRMON_MESH301245   ppb         1126
# PM 4         PER_AIRMON_MESH1911150  ugm -3     16715
#              PER_AIRMON_MESH301245   ugm -3     14334
# PM1          PER_AIRMON_MESH1911150  ugm -3     16713
#              PER_AIRMON_MESH301245   ugm -3     14334
# PM10         PER_AIRMON_MESH1911150  ugm -3     16713
#              PER_AIRMON_MESH301245   ugm -3     14334
# PM2.5        PER_AIRMON_MESH1911150  ugm -3     16714
#              PER_AIRMON_MESH301245   ugm -3     14334
# Pressure     PER_AIRMON_MESH1911150  hpa         1180
#              PER_AIRMON_MESH301245   hpa         1126
# Sound        PER_EMOTE_1309          db         16232
# Temperature  PER_AIRMON_MESH1911150  Celsius     1180
#              PER_AIRMON_MESH301245   Celsius     1126
#              PER_EMOTE_1309          Celsius    17612
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Units","Sensor"])["Sensor"].count()
# Out:
# Type         Units    Sensor
# CO           ugm -3   PER_AIRMON_MESH1911150     1180
#                       PER_EMOTE_1309            16212
# Humidity     %        PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            16994
# NO           ugm -3   PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17612
# NO2          ugm -3   PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17623
# O3           ppb      PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
# PM 4         ugm -3   PER_AIRMON_MESH1911150    16715
#                       PER_AIRMON_MESH301245     14334
# PM1          ugm -3   PER_AIRMON_MESH1911150    16713
#                       PER_AIRMON_MESH301245     14334
# PM10         ugm -3   PER_AIRMON_MESH1911150    16713
#                       PER_AIRMON_MESH301245     14334
# PM2.5        ugm -3   PER_AIRMON_MESH1911150    16714
#                       PER_AIRMON_MESH301245     14334
# Pressure     hpa      PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
# Sound        db       PER_EMOTE_1309            16232
# Temperature  Celsius  PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17612
# Name: Sensor, dtype: int64

# %%
df.groupby(["Units","Type","Sensor"])["Sensor"].count()
# Out:
# Units    Type         Sensor
# %        Humidity     PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            16994
# Celsius  Temperature  PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17612
# db       Sound        PER_EMOTE_1309            16232
# hpa      Pressure     PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
# ppb      O3           PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
# ugm -3   CO           PER_AIRMON_MESH1911150     1180
#                       PER_EMOTE_1309            16212
#          NO           PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17612
#          NO2          PER_AIRMON_MESH1911150     1180
#                       PER_AIRMON_MESH301245      1126
#                       PER_EMOTE_1309            17623
#          PM 4         PER_AIRMON_MESH1911150    16715
#                       PER_AIRMON_MESH301245     14334
#          PM1          PER_AIRMON_MESH1911150    16713
#                       PER_AIRMON_MESH301245     14334
#          PM10         PER_AIRMON_MESH1911150    16713
#                       PER_AIRMON_MESH301245     14334
#          PM2.5        PER_AIRMON_MESH1911150    16714
#                       PER_AIRMON_MESH301245     14334
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type"])["Sensor"].count()
# Out:
# Sensor                  Type
# PER_AIRMON_MESH1911150  CO              1180
#                         Humidity        1180
#                         NO              1180
#                         NO2             1180
#                         O3              1180
#                         PM 4           16715
#                         PM1            16713
#                         PM10           16713
#                         PM2.5          16714
#                         Pressure        1180
#                         Temperature     1180
# PER_AIRMON_MESH301245   Humidity        1126
#                         NO              1126
#                         NO2             1126
#                         O3              1126
#                         PM 4           14334
#                         PM1            14334
#                         PM10           14334
#                         PM2.5          14334
#                         Pressure        1126
#                         Temperature     1126
# PER_EMOTE_1309          CO             16212
#                         Humidity       16994
#                         NO             17612
#                         NO2            17623
#                         Sound          16232
#                         Temperature    17612
# Name: Sensor, dtype: int64

# %%
def combinedPlot(c1,c2,c3,position):
    fig, ax = plt.subplots(figsize=(12,6))
    df.groupby([c1,c2])[c3].count().unstack().plot(ax=ax,kind="bar",stacked=True)
    ax.legend(loc=position,ncol=2, fancybox=True, shadow=True)
    plt.xticks(rotation=0)
    plt.show()

# %%
combinedPlot("Sensor","Type","Units","upper center")

# %%
combinedPlot("Type","Units","Sensor","upper right")

# %%
combinedPlot("Type","Sensor","Sensor","upper left")

# %%
combinedPlot("Sensor","Units","Type","upper center")
