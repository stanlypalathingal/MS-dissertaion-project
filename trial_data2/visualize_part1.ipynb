# %%
# %autosave 20
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Autosaving every 20 seconds

# %%
df=pd.read_csv("Sample dataset values1.csv")
# df_s=df_s.drop("Key",1)
df=df.dropna()
print("sample before ",df.shape)
# Out:
# sample before  (279510, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 279510 entries, 0 to 279509
# Data columns (total 6 columns):
# Sensor    279510 non-null object
# Type      279510 non-null object
# Units     279510 non-null object
# time      279510 non-null object
# Flag      279510 non-null float64
# Value     279510 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 14.9+ MB

# %%
df.nunique()
# Out:
# Sensor        3
# Type         12
# Units         6
# time      30594
# Flag          2
# Value     69445
# dtype: int64

# %%
def plot_cloumns_individual(columnName,type="bar"):
    x=1
    for i in columnName:
        fig.add_subplot(1,3,x)
#         print(df[i].value_counts())
        df[i].value_counts().plot(kind=type)
        
        plt.title(i)
        plt.xticks(rotation=45)
        x=x+1

# %%
# plt.subplot(2,1,2)
fig = plt.figure(figsize=(15,5))
plot_cloumns_individual(["Sensor","Type","Units"],"bar")
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
plot_cloumns_individual(["Sensor","Type","Units"],"pie")
plt.show()

# %%
df.groupby("Type")["Sensor"].count()
# Out:
# Type
# CO             19956
# Humidity       22054
# NO             22672
# NO2            22683
# O3              2687
# PM 4           36373
# PM1            36371
# PM10           36378
# PM2.5          36372
# Pressure        2687
# Sound          18605
# Temperature    22672
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type","Units"])["Sensor"].count()
# Out:
# Sensor                  Type         Units
# PER_AIRMON_MESH1911150  CO           ugm -3      1369
#                         Humidity     %           1369
#                         NO           ugm -3      1369
#                         NO2          ugm -3      1369
#                         O3           ppb         1369
#                         PM 4         ugm -3     19357
#                         PM1          ugm -3     19355
#                         PM10         ugm -3     19362
#                         PM2.5        ugm -3     19356
#                         Pressure     hpa         1369
#                         Temperature  Celsius     1369
# PER_AIRMON_MESH301245   Humidity     %           1318
#                         NO           ugm -3      1318
#                         NO2          ugm -3      1318
#                         O3           ppb         1318
#                         PM 4         ugm -3     17016
#                         PM1          ugm -3     17016
#                         PM10         ugm -3     17016
#                         PM2.5        ugm -3     17016
#                         Pressure     hpa         1318
#                         Temperature  Celsius     1318
# PER_EMOTE_1309          CO           ugm -3     18587
#                         Humidity     %          19367
#                         NO           ugm -3     19985
#                         NO2          ugm -3     19996
#                         Sound        db         18605
#                         Temperature  Celsius    19985
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Sensor","Units"])["Sensor"].count()
# Out:
# Type         Sensor                  Units
# CO           PER_AIRMON_MESH1911150  ugm -3      1369
#              PER_EMOTE_1309          ugm -3     18587
# Humidity     PER_AIRMON_MESH1911150  %           1369
#              PER_AIRMON_MESH301245   %           1318
#              PER_EMOTE_1309          %          19367
# NO           PER_AIRMON_MESH1911150  ugm -3      1369
#              PER_AIRMON_MESH301245   ugm -3      1318
#              PER_EMOTE_1309          ugm -3     19985
# NO2          PER_AIRMON_MESH1911150  ugm -3      1369
#              PER_AIRMON_MESH301245   ugm -3      1318
#              PER_EMOTE_1309          ugm -3     19996
# O3           PER_AIRMON_MESH1911150  ppb         1369
#              PER_AIRMON_MESH301245   ppb         1318
# PM 4         PER_AIRMON_MESH1911150  ugm -3     19357
#              PER_AIRMON_MESH301245   ugm -3     17016
# PM1          PER_AIRMON_MESH1911150  ugm -3     19355
#              PER_AIRMON_MESH301245   ugm -3     17016
# PM10         PER_AIRMON_MESH1911150  ugm -3     19362
#              PER_AIRMON_MESH301245   ugm -3     17016
# PM2.5        PER_AIRMON_MESH1911150  ugm -3     19356
#              PER_AIRMON_MESH301245   ugm -3     17016
# Pressure     PER_AIRMON_MESH1911150  hpa         1369
#              PER_AIRMON_MESH301245   hpa         1318
# Sound        PER_EMOTE_1309          db         18605
# Temperature  PER_AIRMON_MESH1911150  Celsius     1369
#              PER_AIRMON_MESH301245   Celsius     1318
#              PER_EMOTE_1309          Celsius    19985
# Name: Sensor, dtype: int64

# %%
df.groupby(["Type","Units","Sensor"])["Sensor"].count()
# Out:
# Type         Units    Sensor
# CO           ugm -3   PER_AIRMON_MESH1911150     1369
#                       PER_EMOTE_1309            18587
# Humidity     %        PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19367
# NO           ugm -3   PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19985
# NO2          ugm -3   PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19996
# O3           ppb      PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
# PM 4         ugm -3   PER_AIRMON_MESH1911150    19357
#                       PER_AIRMON_MESH301245     17016
# PM1          ugm -3   PER_AIRMON_MESH1911150    19355
#                       PER_AIRMON_MESH301245     17016
# PM10         ugm -3   PER_AIRMON_MESH1911150    19362
#                       PER_AIRMON_MESH301245     17016
# PM2.5        ugm -3   PER_AIRMON_MESH1911150    19356
#                       PER_AIRMON_MESH301245     17016
# Pressure     hpa      PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
# Sound        db       PER_EMOTE_1309            18605
# Temperature  Celsius  PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19985
# Name: Sensor, dtype: int64

# %%
df.groupby(["Units","Type","Sensor"])["Sensor"].count()
# Out:
# Units    Type         Sensor
# %        Humidity     PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19367
# Celsius  Temperature  PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19985
# db       Sound        PER_EMOTE_1309            18605
# hpa      Pressure     PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
# ppb      O3           PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
# ugm -3   CO           PER_AIRMON_MESH1911150     1369
#                       PER_EMOTE_1309            18587
#          NO           PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19985
#          NO2          PER_AIRMON_MESH1911150     1369
#                       PER_AIRMON_MESH301245      1318
#                       PER_EMOTE_1309            19996
#          PM 4         PER_AIRMON_MESH1911150    19357
#                       PER_AIRMON_MESH301245     17016
#          PM1          PER_AIRMON_MESH1911150    19355
#                       PER_AIRMON_MESH301245     17016
#          PM10         PER_AIRMON_MESH1911150    19362
#                       PER_AIRMON_MESH301245     17016
#          PM2.5        PER_AIRMON_MESH1911150    19356
#                       PER_AIRMON_MESH301245     17016
# Name: Sensor, dtype: int64

# %%
df.groupby(["Sensor","Type"])["Sensor"].count()
# Out:
# Sensor                  Type
# PER_AIRMON_MESH1911150  CO              1369
#                         Humidity        1369
#                         NO              1369
#                         NO2             1369
#                         O3              1369
#                         PM 4           19357
#                         PM1            19355
#                         PM10           19362
#                         PM2.5          19356
#                         Pressure        1369
#                         Temperature     1369
# PER_AIRMON_MESH301245   Humidity        1318
#                         NO              1318
#                         NO2             1318
#                         O3              1318
#                         PM 4           17016
#                         PM1            17016
#                         PM10           17016
#                         PM2.5          17016
#                         Pressure        1318
#                         Temperature     1318
# PER_EMOTE_1309          CO             18587
#                         Humidity       19367
#                         NO             19985
#                         NO2            19996
#                         Sound          18605
#                         Temperature    19985
# Name: Sensor, dtype: int64

# %%
def combinedPlot(c1,c2,c3,position):
    fig, ax = plt.subplots(figsize=(12,6))
    df.groupby([c1,c2])[c3].count().unstack().plot(ax=ax,kind="bar",stacked=True)
    ax.legend(loc=position,ncol=2, fancybox=True, shadow=True)
    plt.xticks(rotation=0)
    plt.show()

# %%
combinedPlot("Sensor","Type","Units","upper center")

# %%
combinedPlot("Type","Units","Sensor","upper right")

# %%
combinedPlot("Type","Sensor","Sensor","upper left")

# %%
combinedPlot("Sensor","Units","Type","upper center")

# %%
a=df.groupby(["Sensor","Type","Units"])["Sensor"].unique()
b=df.groupby(["Sensor","Type","Units"])["Sensor"].unique()

# %%
print(a.equals(b))
# Out:
# True

# %%
b
# Out:
# Sensor                  Type         Units
# PER_AIRMON_MESH1911150  CO           ugm -3     [PER_AIRMON_MESH1911150]
#                         Humidity     %          [PER_AIRMON_MESH1911150]
#                         NO           ugm -3     [PER_AIRMON_MESH1911150]
#                         NO2          ugm -3     [PER_AIRMON_MESH1911150]
#                         O3           ppb        [PER_AIRMON_MESH1911150]
#                         PM 4         ugm -3     [PER_AIRMON_MESH1911150]
#                         PM1          ugm -3     [PER_AIRMON_MESH1911150]
#                         PM10         ugm -3     [PER_AIRMON_MESH1911150]
#                         PM2.5        ugm -3     [PER_AIRMON_MESH1911150]
#                         Pressure     hpa        [PER_AIRMON_MESH1911150]
#                         Temperature  Celsius    [PER_AIRMON_MESH1911150]
# PER_AIRMON_MESH301245   Humidity     %           [PER_AIRMON_MESH301245]
#                         NO           ugm -3      [PER_AIRMON_MESH301245]
#                         NO2          ugm -3      [PER_AIRMON_MESH301245]
#                         O3           ppb         [PER_AIRMON_MESH301245]
#                         PM 4         ugm -3      [PER_AIRMON_MESH301245]
#                         PM1          ugm -3      [PER_AIRMON_MESH301245]
#                         PM10         ugm -3      [PER_AIRMON_MESH301245]
#                         PM2.5        ugm -3      [PER_AIRMON_MESH301245]
#                         Pressure     hpa         [PER_AIRMON_MESH301245]
#                         Temperature  Celsius     [PER_AIRMON_MESH301245]
# PER_EMOTE_1309          CO           ugm -3             [PER_EMOTE_1309]
#                         Humidity     %                  [PER_EMOTE_1309]
#                         NO           ugm -3             [PER_EMOTE_1309]
#                         NO2          ugm -3             [PER_EMOTE_1309]
#                         Sound        db                 [PER_EMOTE_1309]
#                         Temperature  Celsius            [PER_EMOTE_1309]
# Name: Sensor, dtype: object
