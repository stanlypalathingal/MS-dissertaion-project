# %%
# %autosave 20
import math 
import pandas as pd
# Out:
# Autosaving every 20 seconds

# %%
# #Load the dataset of Titanic train
# df=pd.read_csv("train.csv")
# df.head()
# df = df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
# df.head()
# df.columns
# xtrain=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked']
# ytrain=['Survived']

# %%
# df=df[xtrain+ytrain]
# df= df.fillna(df.mean())
# # df.loc[df['play']=='no','play']=0
# # df.loc[df['play']=='yes','play']=1
# # df.head() 
# df=df.dropna()
# P,N=df['Survived'].value_counts()
# print("yes :",P)
# print("No :",N)
# df.head()

# %%
#Load the dataset weather
df=pd.read_csv("weather.csv")
df
df.loc[df['play']=='no','play']=0
df.loc[df['play']=='yes','play']=1
df.head() 
P,N=df['play'].value_counts()
print("yes :",P)
print("No :",N)
xtrain=['outlook', 'temperature', 'humidity', 'windy']
ytrain=['play']
df=df[xtrain+ytrain]
# Out:
#      outlook temperature humidity  windy play
# 0      sunny         hot     high  False   no
# 1      sunny         hot     high   True   no
# 2   overcast         hot     high  False  yes
# 3      rainy        mild     high  False  yes
# 4      rainy        cool   normal  False  yes
# 5      rainy        cool   normal   True   no
# 6   overcast        cool   normal   True  yes
# 7      sunny        mild     high  False   no
# 8      sunny        cool   normal  False  yes
# 9      rainy        mild   normal  False  yes
# 10     sunny        mild   normal   True  yes
# 11  overcast        mild     high   True  yes
# 12  overcast         hot   normal  False  yes
# 13     rainy        mild     high   True   no
#     outlook temperature humidity  windy  play
# 0     sunny         hot     high  False     0
# 1     sunny         hot     high   True     0
# 2  overcast         hot     high  False     1
# 3     rainy        mild     high  False     1
# 4     rainy        cool   normal  False     1
# yes : 9
# No : 5

# %%
IG = pd.DataFrame(columns=['column', 'Info_gain'])
Gain = pd.DataFrame(columns=['column', 'gain'])
dependent=''.join(ytrain)

# %%
# Function to calculate information gain
def informationGain(p,n,IG):
    if(p==0):
        return 0
    elif(n==0):
        return 0    
    IG= -(p/(p+n))*math.log2(p/(p+n)) - (n/(p+n))*math.log2(n/(p+n))
    return round(IG,3)

# %%
IG=informationGain(P,N)
print("Total Information Gain : ",IG)
# Out:
# Total Information Gain :  0.94

# %%
def find_gain(new_df,Gain):
    for col in range(0,len(new_df.columns)-1):
        b=new_df.columns[col]
        print(b)
        cmn=[]

        cmn=new_df.iloc[:,col].unique()
        ig=[]
        p1=[]
        n1=[]


        for col1 in range(0,len(cmn)):
            p=n=0
            print(cmn[col1])
            s=new_df.groupby(b).get_group(cmn[col1])
            print(s)
            p=len(s[s[dependent]==1])
            n=len(s[s[dependent]==0])    
            print(p)
            print(n)
            ig.append(informationGain(p,n))
            p1.append(p)
            n1.append(n)
            print("information gain of ",cmn[col1], "is ",ig[col1])

        E=0.0
        for i in range(0,len(cmn)):
            E=E+(((p1[i]+n1[i])/(P+N))*ig[i])

        print("Entropy of ", b, "is ",round(E,3))
        print("Gain of ",b, "is ",round(IG-E,3))
        Gain=Gain.append([{'column':b,'gain':round(IG-E,3)}], ignore_index=True)

#         print(Gain)
        print("***********")  
    
    return Gain

# %%
Gain=find_gain(df,Gain)
print(Gain.sort_values(by=['gain'],ascending=False))
# Out:
# outlook
# sunny
#    outlook temperature humidity  windy  play
# 0    sunny         hot     high  False     0
# 1    sunny         hot     high   True     0
# 7    sunny        mild     high  False     0
# 8    sunny        cool   normal  False     1
# 10   sunny        mild   normal   True     1
# 2
# 3
# information gain of  sunny is  0.971
# overcast
#      outlook temperature humidity  windy  play
# 2   overcast         hot     high  False     1
# 6   overcast        cool   normal   True     1
# 11  overcast        mild     high   True     1
# 12  overcast         hot   normal  False     1
# 4
# 0
# information gain of  overcast is  0
# rainy
#    outlook temperature humidity  windy  play
# 3    rainy        mild     high  False     1
# 4    rainy        cool   normal  False     1
# 5    rainy        cool   normal   True     0
# 9    rainy        mild   normal  False     1
# 13   rainy        mild     high   True     0
# 3
# 2
# information gain of  rainy is  0.971
# Entropy of  outlook is  0.694
# Gain of  outlook is  0.246
# ***********
# temperature
# hot
#      outlook temperature humidity  windy  play
# 0      sunny         hot     high  False     0
# 1      sunny         hot     high   True     0
# 2   overcast         hot     high  False     1
# 12  overcast         hot   normal  False     1
# 2
# 2
# information gain of  hot is  1.0
# mild
#      outlook temperature humidity  windy  play
# 3      rainy        mild     high  False     1
# 7      sunny        mild     high  False     0
# 9      rainy        mild   normal  False     1
# 10     sunny        mild   normal   True     1
# 11  overcast        mild     high   True     1
# 13     rainy        mild     high   True     0
# 4
# 2
# information gain of  mild is  0.918
# cool
#     outlook temperature humidity  windy  play
# 4     rainy        cool   normal  False     1
# 5     rainy        cool   normal   True     0
# 6  overcast        cool   normal   True     1
# 8     sunny        cool   normal  False     1
# 3
# 1
# information gain of  cool is  0.811
# Entropy of  temperature is  0.911
# Gain of  temperature is  0.029
# ***********
# humidity
# high
#      outlook temperature humidity  windy  play
# 0      sunny         hot     high  False     0
# 1      sunny         hot     high   True     0
# 2   overcast         hot     high  False     1
# 3      rainy        mild     high  False     1
# 7      sunny        mild     high  False     0
# 11  overcast        mild     high   True     1
# 13     rainy        mild     high   True     0
# 3
# 4
# information gain of  high is  0.985
# normal
#      outlook temperature humidity  windy  play
# 4      rainy        cool   normal  False     1
# 5      rainy        cool   normal   True     0
# 6   overcast        cool   normal   True     1
# 8      sunny        cool   normal  False     1
# 9      rainy        mild   normal  False     1
# 10     sunny        mild   normal   True     1
# 12  overcast         hot   normal  False     1
# 6
# 1
# information gain of  normal is  0.592
# Entropy of  humidity is  0.788
# Gain of  humidity is  0.151
# ***********
# windy
# False
#      outlook temperature humidity  windy  play
# 0      sunny         hot     high  False     0
# 2   overcast         hot     high  False     1
# 3      rainy        mild     high  False     1
# 4      rainy        cool   normal  False     1
# 7      sunny        mild     high  False     0
# 8      sunny        cool   normal  False     1
# 9      rainy        mild   normal  False     1
# 12  overcast         hot   normal  False     1
# 6
# 2
# information gain of  False is  0.811
# True
#      outlook temperature humidity  windy  play
# 1      sunny         hot     high   True     0
# 5      rainy        cool   normal   True     0
# 6   overcast        cool   normal   True     1
# 10     sunny        mild   normal   True     1
# 11  overcast        mild     high   True     1
# 13     rainy        mild     high   True     0
# 3
# 3
# information gain of  True is  1.0
# Entropy of  windy is  0.892
# Gain of  windy is  0.048
# ***********
#         column   gain
# 0      outlook  0.246
# 2     humidity  0.151
# 3        windy  0.048
# 1  temperature  0.029

# %%
print(Gain.sort_values(by=['gain'],ascending=False))
c=Gain.sort_values(by=['gain'],ascending=False).column.tolist()
c.append(dependent)
c
# Out:
#         column   gain
# 0      outlook  0.246
# 2     humidity  0.151
# 3        windy  0.048
# 1  temperature  0.029
# ['outlook', 'humidity', 'windy', 'temperature', 'play']

# %%
df=df[c]
df.head()
# Out:
#     outlook humidity  windy temperature  play
# 0     sunny     high  False         hot     0
# 1     sunny     high   True         hot     0
# 2  overcast     high  False         hot     1
# 3     rainy     high  False        mild     1
# 4     rainy   normal  False        cool     1

# %%
def find_gain2(new_df,Gain):
    for col in range(1,len(new_df.columns)-1):
        b=new_df.columns[col]
        print(b)
        cmn=[]
        
        cmn=new_df.iloc[:,col].unique()
        ig=[]
        p1=[]
        n1=[]


        for col1 in range(0,len(cmn)):
            p=n=0
            print(cmn[col1])
            s=new_df.groupby(b).get_group(cmn[col1])
            print(s)
            p=len(s[s[dependent]==1])
            n=len(s[s[dependent]==0])    
            print(p)
            print(n)
            ig.append(informationGain(p,n))
            p1.append(p)
            n1.append(n)
            print("information gain of ",cmn[col1], "is ",ig[col1])

        E=0.0
        for i in range(0,len(cmn)):
            E=E+(((p1[i]+n1[i])/(P+N))*ig[i])

        print("Entropy of ", b, "is ",round(E,3))
        print("Gain of ",b, "is ",round(IG-E,3))
        Gain=Gain.append([{'column':b,'gain':round(IG-E,3)}], ignore_index=True)

#         print(Gain)
        print("***********")  
    
    return Gain

# %%
for col in range(0,len(df.columns)-1):
        b=df.columns[col]
#         print(b)
        cmn=[]

        cmn=df.iloc[:,col].unique()
        ig=[]
        p1=[]
        n1=[]


        for col1 in range(0,len(cmn)):
            p=n=0
            print(cmn[col1])
            s=df.groupby(b).get_group(cmn[col1])
#             print(s)
            Gain_2=find_gain2(s,Gain)
# Out:
# sunny
# humidity
# high
#   outlook humidity  windy temperature  play
# 0   sunny     high  False         hot     0
# 1   sunny     high   True         hot     0
# 7   sunny     high  False        mild     0
# 0
# 3
# information gain of  high is  0
# normal
#    outlook humidity  windy temperature  play
# 8    sunny   normal  False        cool     1
# 10   sunny   normal   True        mild     1
# 2
# 0
# information gain of  normal is  0
# Entropy of  humidity is  0.0
# Gain of  humidity is  0.94
# ***********
# windy
# False
#   outlook humidity  windy temperature  play
# 0   sunny     high  False         hot     0
# 7   sunny     high  False        mild     0
# 8   sunny   normal  False        cool     1
# 1
# 2
# information gain of  False is  0.918
# True
#    outlook humidity  windy temperature  play
# 1    sunny     high   True         hot     0
# 10   sunny   normal   True        mild     1
# 1
# 1
# information gain of  True is  1.0
# Entropy of  windy is  0.34
# Gain of  windy is  0.6
# ***********
# temperature
# hot
#   outlook humidity  windy temperature  play
# 0   sunny     high  False         hot     0
# 1   sunny     high   True         hot     0
# 0
# 2
# information gain of  hot is  0
# mild
#    outlook humidity  windy temperature  play
# 7    sunny     high  False        mild     0
# 10   sunny   normal   True        mild     1
# 1
# 1
# information gain of  mild is  1.0
# cool
#   outlook humidity  windy temperature  play
# 8   sunny   normal  False        cool     1
# 1
# 0
# information gain of  cool is  0
# Entropy of  temperature is  0.143
# Gain of  temperature is  0.797
# ***********
# overcast
# humidity
# high
#      outlook humidity  windy temperature  play
# 2   overcast     high  False         hot     1
# 11  overcast     high   True        mild     1
# 2
# 0
# information gain of  high is  0
# normal
#      outlook humidity  windy temperature  play
# 6   overcast   normal   True        cool     1
# 12  overcast   normal  False         hot     1
# 2
# 0
# information gain of  normal is  0
# Entropy of  humidity is  0.0
# Gain of  humidity is  0.94
# ***********
# windy
# False
#      outlook humidity  windy temperature  play
# 2   overcast     high  False         hot     1
# 12  overcast   normal  False         hot     1
# 2
# 0
# information gain of  False is  0
# True
#      outlook humidity  windy temperature  play
# 6   overcast   normal   True        cool     1
# 11  overcast     high   True        mild     1
# 2
# 0
# information gain of  True is  0
# Entropy of  windy is  0.0
# Gain of  windy is  0.94
# ***********
# temperature
# hot
#      outlook humidity  windy temperature  play
# 2   overcast     high  False         hot     1
# 12  overcast   normal  False         hot     1
# 2
# 0
# information gain of  hot is  0
# cool
#     outlook humidity  windy temperature  play
# 6  overcast   normal   True        cool     1
# 1
# 0
# information gain of  cool is  0
# mild
#      outlook humidity  windy temperature  play
# 11  overcast     high   True        mild     1
# 1
# 0
# information gain of  mild is  0
# Entropy of  temperature is  0.0
# Gain of  temperature is  0.94
# ***********
# rainy
# humidity
# high
#    outlook humidity  windy temperature  play
# 3    rainy     high  False        mild     1
# 13   rainy     high   True        mild     0
# 1
# 1
# information gain of  high is  1.0
# normal
#   outlook humidity  windy temperature  play
# 4   rainy   normal  False        cool     1
# 5   rainy   normal   True        cool     0
# 9   rainy   normal  False        mild     1
# 2
# 1
# information gain of  normal is  0.918
# Entropy of  humidity is  0.34
# Gain of  humidity is  0.6
# ***********
# windy
# False
#   outlook humidity  windy temperature  play
# 3   rainy     high  False        mild     1
# 4   rainy   normal  False        cool     1
# 9   rainy   normal  False        mild     1
# 3
# 0
# information gain of  False is  0
# True
#    outlook humidity  windy temperature  play
# 5    rainy   normal   True        cool     0
# 13   rainy     high   True        mild     0
# 0
# 2
# information gain of  True is  0
# Entropy of  windy is  0.0
# Gain of  windy is  0.94
# ***********
# temperature
# mild
#    outlook humidity  windy temperature  play
# 3    rainy     high  False        mild     1
# 9    rainy   normal  False        mild     1
# 13   rainy     high   True        mild     0
# 2
# 1
# information gain of  mild is  0.918
# cool
#   outlook humidity  windy temperature  play
# 4   rainy   normal  False        cool     1
# 5   rainy   normal   True        cool     0
# 1
# 1
# information gain of  cool is  1.0
# Entropy of  temperature is  0.34
# Gain of  temperature is  0.6
# ***********
# high
# humidity
# high
#      outlook humidity  windy temperature  play
# 0      sunny     high  False         hot     0
# 1      sunny     high   True         hot     0
# 2   overcast     high  False         hot     1
# 3      rainy     high  False        mild     1
# 7      sunny     high  False        mild     0
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 3
# 4
# information gain of  high is  0.985
# Entropy of  humidity is  0.492
# Gain of  humidity is  0.447
# ***********
# windy
# False
#     outlook humidity  windy temperature  play
# 0     sunny     high  False         hot     0
# 2  overcast     high  False         hot     1
# 3     rainy     high  False        mild     1
# 7     sunny     high  False        mild     0
# 2
# 2
# information gain of  False is  1.0
# True
#      outlook humidity  windy temperature  play
# 1      sunny     high   True         hot     0
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 1
# 2
# information gain of  True is  0.918
# Entropy of  windy is  0.482
# Gain of  windy is  0.458
# ***********
# temperature
# hot
#     outlook humidity  windy temperature  play
# 0     sunny     high  False         hot     0
# 1     sunny     high   True         hot     0
# 2  overcast     high  False         hot     1
# 1
# 2
# information gain of  hot is  0.918
# mild
#      outlook humidity  windy temperature  play
# 3      rainy     high  False        mild     1
# 7      sunny     high  False        mild     0
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 2
# 2
# information gain of  mild is  1.0
# Entropy of  temperature is  0.482
# Gain of  temperature is  0.458
# ***********
# normal
# humidity
# normal
#      outlook humidity  windy temperature  play
# 4      rainy   normal  False        cool     1
# 5      rainy   normal   True        cool     0
# 6   overcast   normal   True        cool     1
# 8      sunny   normal  False        cool     1
# 9      rainy   normal  False        mild     1
# 10     sunny   normal   True        mild     1
# 12  overcast   normal  False         hot     1
# 6
# 1
# information gain of  normal is  0.592
# Entropy of  humidity is  0.296
# Gain of  humidity is  0.644
# ***********
# windy
# False
#      outlook humidity  windy temperature  play
# 4      rainy   normal  False        cool     1
# 8      sunny   normal  False        cool     1
# 9      rainy   normal  False        mild     1
# 12  overcast   normal  False         hot     1
# 4
# 0
# information gain of  False is  0
# True
#      outlook humidity  windy temperature  play
# 5      rainy   normal   True        cool     0
# 6   overcast   normal   True        cool     1
# 10     sunny   normal   True        mild     1
# 2
# 1
# information gain of  True is  0.918
# Entropy of  windy is  0.197
# Gain of  windy is  0.743
# ***********
# temperature
# cool
#     outlook humidity  windy temperature  play
# 4     rainy   normal  False        cool     1
# 5     rainy   normal   True        cool     0
# 6  overcast   normal   True        cool     1
# 8     sunny   normal  False        cool     1
# 3
# 1
# information gain of  cool is  0.811
# mild
#    outlook humidity  windy temperature  play
# 9    rainy   normal  False        mild     1
# 10   sunny   normal   True        mild     1
# 2
# 0
# information gain of  mild is  0
# hot
#      outlook humidity  windy temperature  play
# 12  overcast   normal  False         hot     1
# 1
# 0
# information gain of  hot is  0
# Entropy of  temperature is  0.232
# Gain of  temperature is  0.708
# ***********
# False
# humidity
# high
#     outlook humidity  windy temperature  play
# 0     sunny     high  False         hot     0
# 2  overcast     high  False         hot     1
# 3     rainy     high  False        mild     1
# 7     sunny     high  False        mild     0
# 2
# 2
# information gain of  high is  1.0
# normal
#      outlook humidity  windy temperature  play
# 4      rainy   normal  False        cool     1
# 8      sunny   normal  False        cool     1
# 9      rainy   normal  False        mild     1
# 12  overcast   normal  False         hot     1
# 4
# 0
# information gain of  normal is  0
# Entropy of  humidity is  0.286
# Gain of  humidity is  0.654
# ***********
# windy
# False
#      outlook humidity  windy temperature  play
# 0      sunny     high  False         hot     0
# 2   overcast     high  False         hot     1
# 3      rainy     high  False        mild     1
# 4      rainy   normal  False        cool     1
# 7      sunny     high  False        mild     0
# 8      sunny   normal  False        cool     1
# 9      rainy   normal  False        mild     1
# 12  overcast   normal  False         hot     1
# 6
# 2
# information gain of  False is  0.811
# Entropy of  windy is  0.463
# Gain of  windy is  0.477
# ***********
# temperature
# hot
#      outlook humidity  windy temperature  play
# 0      sunny     high  False         hot     0
# 2   overcast     high  False         hot     1
# 12  overcast   normal  False         hot     1
# 2
# 1
# information gain of  hot is  0.918
# mild
#   outlook humidity  windy temperature  play
# 3   rainy     high  False        mild     1
# 7   sunny     high  False        mild     0
# 9   rainy   normal  False        mild     1
# 2
# 1
# information gain of  mild is  0.918
# cool
#   outlook humidity  windy temperature  play
# 4   rainy   normal  False        cool     1
# 8   sunny   normal  False        cool     1
# 2
# 0
# information gain of  cool is  0
# Entropy of  temperature is  0.393
# Gain of  temperature is  0.547
# ***********
# True
# humidity
# high
#      outlook humidity  windy temperature  play
# 1      sunny     high   True         hot     0
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 1
# 2
# information gain of  high is  0.918
# normal
#      outlook humidity  windy temperature  play
# 5      rainy   normal   True        cool     0
# 6   overcast   normal   True        cool     1
# 10     sunny   normal   True        mild     1
# 2
# 1
# information gain of  normal is  0.918
# Entropy of  humidity is  0.393
# Gain of  humidity is  0.547
# ***********
# windy
# True
#      outlook humidity  windy temperature  play
# 1      sunny     high   True         hot     0
# 5      rainy   normal   True        cool     0
# 6   overcast   normal   True        cool     1
# 10     sunny   normal   True        mild     1
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 3
# 3
# information gain of  True is  1.0
# Entropy of  windy is  0.429
# Gain of  windy is  0.511
# ***********
# temperature
# hot
#   outlook humidity  windy temperature  play
# 1   sunny     high   True         hot     0
# 0
# 1
# information gain of  hot is  0
# cool
#     outlook humidity  windy temperature  play
# 5     rainy   normal   True        cool     0
# 6  overcast   normal   True        cool     1
# 1
# 1
# information gain of  cool is  1.0
# mild
#      outlook humidity  windy temperature  play
# 10     sunny   normal   True        mild     1
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 2
# 1
# information gain of  mild is  0.918
# Entropy of  temperature is  0.34
# Gain of  temperature is  0.6
# ***********
# hot
# humidity
# high
#     outlook humidity  windy temperature  play
# 0     sunny     high  False         hot     0
# 1     sunny     high   True         hot     0
# 2  overcast     high  False         hot     1
# 1
# 2
# information gain of  high is  0.918
# normal
#      outlook humidity  windy temperature  play
# 12  overcast   normal  False         hot     1
# 1
# 0
# information gain of  normal is  0
# Entropy of  humidity is  0.197
# Gain of  humidity is  0.743
# ***********
# windy
# False
#      outlook humidity  windy temperature  play
# 0      sunny     high  False         hot     0
# 2   overcast     high  False         hot     1
# 12  overcast   normal  False         hot     1
# 2
# 1
# information gain of  False is  0.918
# True
#   outlook humidity  windy temperature  play
# 1   sunny     high   True         hot     0
# 0
# 1
# information gain of  True is  0
# Entropy of  windy is  0.197
# Gain of  windy is  0.743
# ***********
# temperature
# hot
#      outlook humidity  windy temperature  play
# 0      sunny     high  False         hot     0
# 1      sunny     high   True         hot     0
# 2   overcast     high  False         hot     1
# 12  overcast   normal  False         hot     1
# 2
# 2
# information gain of  hot is  1.0
# Entropy of  temperature is  0.286
# Gain of  temperature is  0.654
# ***********
# mild
# humidity
# high
#      outlook humidity  windy temperature  play
# 3      rainy     high  False        mild     1
# 7      sunny     high  False        mild     0
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 2
# 2
# information gain of  high is  1.0
# normal
#    outlook humidity  windy temperature  play
# 9    rainy   normal  False        mild     1
# 10   sunny   normal   True        mild     1
# 2
# 0
# information gain of  normal is  0
# Entropy of  humidity is  0.286
# Gain of  humidity is  0.654
# ***********
# windy
# False
#   outlook humidity  windy temperature  play
# 3   rainy     high  False        mild     1
# 7   sunny     high  False        mild     0
# 9   rainy   normal  False        mild     1
# 2
# 1
# information gain of  False is  0.918
# True
#      outlook humidity  windy temperature  play
# 10     sunny   normal   True        mild     1
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 2
# 1
# information gain of  True is  0.918
# Entropy of  windy is  0.393
# Gain of  windy is  0.547
# ***********
# temperature
# mild
#      outlook humidity  windy temperature  play
# 3      rainy     high  False        mild     1
# 7      sunny     high  False        mild     0
# 9      rainy   normal  False        mild     1
# 10     sunny   normal   True        mild     1
# 11  overcast     high   True        mild     1
# 13     rainy     high   True        mild     0
# 4
# 2
# information gain of  mild is  0.918
# Entropy of  temperature is  0.393
# Gain of  temperature is  0.547
# ***********
# cool
# humidity
# normal
#     outlook humidity  windy temperature  play
# 4     rainy   normal  False        cool     1
# 5     rainy   normal   True        cool     0
# 6  overcast   normal   True        cool     1
# 8     sunny   normal  False        cool     1
# 3
# 1
# information gain of  normal is  0.811
# Entropy of  humidity is  0.232
# Gain of  humidity is  0.708
# ***********
# windy
# False
#   outlook humidity  windy temperature  play
# 4   rainy   normal  False        cool     1
# 8   sunny   normal  False        cool     1
# 2
# 0
# information gain of  False is  0
# True
#     outlook humidity  windy temperature  play
# 5     rainy   normal   True        cool     0
# 6  overcast   normal   True        cool     1
# 1
# 1
# information gain of  True is  1.0
# Entropy of  windy is  0.143
# Gain of  windy is  0.797
# ***********
# temperature
# cool
#     outlook humidity  windy temperature  play
# 4     rainy   normal  False        cool     1
# 5     rainy   normal   True        cool     0
# 6  overcast   normal   True        cool     1
# 8     sunny   normal  False        cool     1
# 3
# 1
# information gain of  cool is  0.811
# Entropy of  temperature is  0.232
# Gain of  temperature is  0.708
# ***********

# %%
print(Gain)
# Out:
#         column   gain
# 0      outlook  0.246
# 1  temperature  0.029
# 2     humidity  0.151
# 3        windy  0.048
